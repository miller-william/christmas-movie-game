# %%
import pandas as pd

# %%
df = pd.read_csv('christmas_movies.csv')

# %%
df.dropna()
# Out:
#                                      title rating  runtime  imdb_rating  \
# 0                            Love Actually      R    135.0          7.6
# 1    National Lampoon's Christmas Vacation  PG-13     97.0          7.5
# 3                               Home Alone     PG    103.0          7.7
# 4           How the Grinch Stole Christmas     PG    104.0          6.3
# 5                                      Elf     PG     97.0          7.1
# ..                                     ...    ...      ...          ...
# 162                                   Rent  PG-13    135.0          6.8
# 175                       Tokyo Godfathers  PG-13     92.0          7.8
# 188                        Charlotte's Web      G     97.0          6.3
# 206        Kirk Cameron's Saving Christmas     PG     79.0          1.3
# 587                            Beat Street     PG    105.0          6.5
#
#      meta_score                         genre  release_year  \
# ...
